# %% [markdown]
# # HSV COLOR PICKER

# %%
cap = cv2.VideoCapture(0)

# %%
# from: https://stackoverflow.com/a/59906154

import cv2
import numpy as np

def nothing(x):
    pass

# Load image
img = "IMG_20220617_094453"
image = cv2.imread("Tensorflow/workspace/images/train/{}.jpg".format(img))
#img = "WIN_20220707_16_53_40_Pro"
#image = cv2.imread("C:/Users/Adnan/Pictures/Camera Roll/{}.jpg".format(img))
image = cv2.resize(image, (1200, 700))
# Create a window
cv2.namedWindow('image')

# Create trackbars for color change
# Hue is from 0-179 for Opencv
cv2.createTrackbar('HMin', 'image', 0, 179, nothing)
cv2.createTrackbar('SMin', 'image', 0, 255, nothing)
cv2.createTrackbar('VMin', 'image', 0, 255, nothing)
cv2.createTrackbar('HMax', 'image', 0, 179, nothing)
cv2.createTrackbar('SMax', 'image', 0, 255, nothing)
cv2.createTrackbar('VMax', 'image', 0, 255, nothing)

# Set default value for Max HSV trackbars
cv2.setTrackbarPos('HMax', 'image', 179)
cv2.setTrackbarPos('SMax', 'image', 255)
cv2.setTrackbarPos('VMax', 'image', 255)

# Initialize HSV min/max values
hMin = sMin = vMin = hMax = sMax = vMax = 0
phMin = psMin = pvMin = phMax = psMax = pvMax = 0

while(1):
    # Get current positions of all trackbars
    hMin = cv2.getTrackbarPos('HMin', 'image')
    sMin = cv2.getTrackbarPos('SMin', 'image')
    vMin = cv2.getTrackbarPos('VMin', 'image')
    hMax = cv2.getTrackbarPos('HMax', 'image')
    sMax = cv2.getTrackbarPos('SMax', 'image')
    vMax = cv2.getTrackbarPos('VMax', 'image')

    # Set minimum and maximum HSV values to display
    lower = np.array([hMin, sMin, vMin])
    upper = np.array([hMax, sMax, vMax])

    # Convert to HSV format and color threshold
    hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
    mask = cv2.inRange(hsv, lower, upper)
    result = cv2.bitwise_and(image, image, mask=mask)

    # Print if there is a change in HSV value
    if((phMin != hMin) | (psMin != sMin) | (pvMin != vMin) | (phMax != hMax) | (psMax != sMax) | (pvMax != vMax) ):
        print("(hMin = %d , sMin = %d, vMin = %d), (hMax = %d , sMax = %d, vMax = %d)" % (hMin , sMin , vMin, hMax, sMax , vMax))
        phMin = hMin
        psMin = sMin
        pvMin = vMin
        phMax = hMax
        psMax = sMax
        pvMax = vMax

    # Display result image
    cv2.imshow('image', result)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cv2.destroyAllWindows()
# Out:
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 2, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 4, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 5, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 6, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 7, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 8, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 9, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 10, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 11, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 13, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 14, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 15, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 16, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 17, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 18, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 19, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 20, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 21, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 23, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 24, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 26, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 27, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 28, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 31, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 35, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 34, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 33, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 32, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 31, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 30, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 29, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 28, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 27, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 26, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 25, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 24, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 23, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 22, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 21, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 20, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 19, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 18, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 17, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 16, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 15, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 14, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 13, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 12, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 11, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 10, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 9, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 8, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 6, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 5, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 4, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 3, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 2, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 1, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 0 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 14 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 22 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 33 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 46 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 56 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 66 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 69 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 75 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 79 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 83 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 85 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 87 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 89 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 91 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 93 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 99 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 108 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 112 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 113 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 114 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 115 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 116 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 117 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 118 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 119 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 120 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 122 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 123 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 124 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 125 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 126 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 128 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 129 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 128 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 126 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 123 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 121 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 119 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 116 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 114 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 112 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 111 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 110 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 109 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 107 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 105 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 104 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 103 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 102 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 101 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 179 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 178 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 175 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 169 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 161 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 149 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 134 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 128 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 124 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 121 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 117 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 112 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 111 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 110 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 108 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 109 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 114 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 120 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 122 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 123 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 124 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 125 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 126 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 127 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 128 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 129 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 0, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 2, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 5, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 8, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 10, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 11, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 12, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 13, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 14, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 15, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 16, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 17, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 18, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 20, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 21, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 22, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 24, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 26, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 32, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 34, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 35, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 36, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 37, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 38, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 39, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 40, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 42, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 43, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 44, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 46, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 48, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 49, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 50, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 51, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 52, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 53, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 54, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 55, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 56, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 57, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 58, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 59, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 57, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 56, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin = 55, vMin = 0), (hMax = 130 , sMax = 255, vMax = 255)
# (hMin = 100 , sMin =